# %% [markdown]
# <a href="https://colab.research.google.com/github/smchakma/ResearchWithSkillMoprh/blob/main/4th_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/Datasets/healthcare_cybersecurity_10k.csv'

df = pd.read_csv(file_path)
print('loaded: ', df.shape)
# Out:
# loaded:  (1515, 11)

# %%
df.head()
# Out:
#            CVE_ID         Keyword   Published Last_Modified    Status  \
# 0   CVE-2011-3386  medical device  2011-09-02    2025-04-11  Deferred
# 1  CVE-2017-12718  medical device  2018-02-15    2024-11-21  Modified
# 2  CVE-2017-14002  medical device  2018-03-20    2024-11-21  Modified
# 3  CVE-2017-14006  medical device  2018-03-20    2024-11-21  Modified
# 4   CVE-2019-5024  medical device  2019-04-11    2024-11-21  Modified
#
#                                          Description Severity  CVSS_Score  \
# 0  Unspecified vulnerability in Medtronic Paradig...   MEDIUM         4.0
# 1  A Classic Buffer Overflow issue was discovered...   MEDIUM         6.8
# 2  GE Infinia/Infinia with Hawkeye 4 medical imag...     HIGH        10.0
# 3  GE Xeleris versions 1.0,1.1,2.1,3.0,3.1, medic...     HIGH         7.5
# 4  A restricted environment escape vulnerability ...     HIGH         7.6
#
#   Attack_Vector        Weakness  \
# 0       NETWORK  NVD-CWE-noinfo
# ...

# %%
df.describe()
# Out:
#         CVSS_Score
# count  1497.000000
# mean      6.554108
# std       1.956064
# min       1.900000
# 25%       5.400000
# 50%       6.500000
# 75%       7.600000
# max      10.000000

# %%
df.tail()
# Out:
#               CVE_ID Keyword   Published Last_Modified    Status  \
# 1510  CVE-2023-32781     HL7  2023-08-09    2024-11-21  Modified
# 1511  CVE-2023-28465     HL7  2023-12-12    2025-05-27  Modified
# 1512  CVE-2024-52807     HL7  2025-01-24    2026-04-15  Deferred
# 1513  CVE-2025-24363     HL7  2025-01-24    2026-04-15  Deferred
# 1514  CVE-2025-53948     HL7  2025-08-18    2025-10-17  Analyzed
#
#                                             Description Severity  CVSS_Score  \
# 1510  A command injection vulnerability was identifi...     HIGH         7.2
# 1511  The package-decompression feature in HL7 (Heal...     HIGH         7.5
# 1512  The HL7 FHIR IG publisher is a tool to take a ...     HIGH         8.6
# 1513  The HL7 FHIR IG publisher is a tool to take a ...   MEDIUM         4.2
# 1514  The Sante PACS Server allows a remote attacker...     HIGH         7.5
#
#      Attack_Vector Weakness                                          Reference
# ...

# %%
print('Missing per column: \n', df.isnull().sum())
print('\nClass Balance: \n', df['Severity'].value_counts())
# Out:
# Missing per column:
#  CVE_ID            0
# Keyword           0
# Published         0
# Last_Modified     0
# Status            0
# Description       0
# Severity         18
# CVSS_Score       18
# Attack_Vector    18
# Weakness          1
# Reference         0
# dtype: int64
#
# Class Balance:
#  Severity
# MEDIUM      720
# HIGH        492
# CRITICAL    151
# LOW         134
# Name: count, dtype: int64
