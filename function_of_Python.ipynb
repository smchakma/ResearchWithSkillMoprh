# %% [markdown]
# <a href="https://colab.research.google.com/github/smchakma/ResearchWithSkillMoprh/blob/main/function_of_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #H1. Write a function to calculate the sum of numbers from 1 to N.

# %%
def sum_to_n(n):
  sum =0
  for i in range(1, n+1):
    sum += i
  return sum

print(sum_to_n(50))
# Out:
# 1275

# %% [markdown]
# #H2. Write a function that returns the square of a number.

# %%
def square(n):
  return n*n

print(square(5))
# Out:
# 25

# %% [markdown]
# #H3. Write a function that checks whether a number is even/odd.

# %%
def even_odd(n):
  if n%2 == 0:
    return "even"
  else:
    return "odd"

print(even_odd(115469))
# Out:
# odd

# %% [markdown]
# #H4. Write a function that returns the larger number from two given numbers.

# %%
def larger_num(a, b):
    if a > b:
        return a
    else:
        return b

    print(larger_num(10, 5))
